# %%
import pandas as pd

df_1 = pd.read_parquet("parquets/SentenceTransformer.parquet")
df_2 = pd.read_parquet("parquets/SenTransformerMulti_qa.parquet")
df_3 = pd.read_parquet("parquets/SenTransformerMinilm_l12.parquet")

df = pd.concat([df_1, df_2, df_3], ignore_index=True)

# %%
df.loc[0, "Method"] = "SenTransformer_minilm_l6"

# %%
df
# Out:
#                       Method  recall_5_mean  recall_5_std  recall_5_max  \
# 0   SenTransformer_minilm_l6      12.089882     12.455515     66.666667
# 1    SenTransformer multi_qa      11.927286     11.864656     71.428571
# 2  SenTransformer minilm_l12      12.984136     12.349759     83.333333
#
#    recall_5_min  recall_10_mean  recall_10_std  recall_10_max  recall_10_min  \
# 0           0.0       15.568538      15.745450      85.714286            0.0
# 1           0.0       15.364111      15.377768     100.000000            0.0
# 2           0.0       16.480406      15.229594     100.000000            0.0
#
#    precision_5_mean  ...     MAP_5    MAP_10  NDCG_5_mean  NDCG_5_std  \
# 0         27.049861  ...  0.093745  0.111715     0.695169    0.365791
# 1         26.855956  ...  0.093419  0.111127     0.715174    0.354878
# 2         28.573407  ...  0.099883  0.118783     0.708287    0.353963
#
#    NDCG_5_max  NDCG_5_min  NDCG_10_mean  NDCG_10_std  NDCG_10_max  NDCG_10_min
# 0         1.0         0.0      0.703160     0.310758          1.0          0.0
# 1         1.0         0.0      0.714065     0.300219          1.0          0.0
# 2         1.0         0.0      0.709100     0.296196          1.0          0.0
#
# [3 rows x 35 columns]

# %%
df["f_score_10_mean"]
# Out:
# 0    14.959802
# 1    14.739899
# 2    15.786780
# Name: f_score_10_mean, dtype: float64

# %%
df.dtypes
# Out:
# Method                   str
# recall_5_mean        float64
# recall_5_std         float64
# recall_5_max         float64
# recall_5_min         float64
# recall_10_mean       float64
# recall_10_std        float64
# recall_10_max        float64
# recall_10_min        float64
# precision_5_mean     float64
# precision_5_std      float64
# precision_5_max      float64
# precision_5_min      float64
# precision_10_mean    float64
# precision_10_std     float64
# precision_10_max     float64
# precision_10_min     float64
# f_score_5_mean       float64
# f_score_5_std        float64
# f_score_5_max        float64
# f_score_5_min        float64
# f_score_10_mean      float64
# f_score_10_std       float64
# f_score_10_max       float64
# f_score_10_min       float64
# MAP_5                float64
# MAP_10               float64
# NDCG_5_mean          float64
# NDCG_5_std           float64
# NDCG_5_max           float64
# NDCG_5_min           float64
# NDCG_10_mean         float64
# NDCG_10_std          float64
# NDCG_10_max          float64
# NDCG_10_min          float64
# dtype: object
