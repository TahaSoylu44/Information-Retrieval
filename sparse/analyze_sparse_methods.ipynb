# %%
import pandas as pd

df_1 = pd.read_parquet("parquets/BagofWordsPorterStemmerQueriesStemmed.parquet")
df_2 = pd.read_parquet("parquets/BagofWordsLemmatization.parquet")
df_3 = pd.read_parquet("parquets/TF-IDFPorterStemmerQueriesStemmed.parquet")
df_4 = pd.read_parquet("parquets/TF-IDFLemmatization.parquet")
df_5 = pd.read_parquet("parquets/BM25PorterStemmerQueriesStemmed.parquet")
df_6 = pd.read_parquet("parquets/BM25Lemmatization.parquet")
df_7 = pd.read_parquet("parquets/BM25-LemmatizationNumbersReplaced.parquet")
df_8 = pd.read_parquet("parquets/BM25LemmatizationNumbersDeleted.parquet")
df_9 = pd.read_parquet("parquets/BM25LemmatizationCrossEncoder.parquet")
df_10 = pd.read_parquet("parquets/BM25LemmatizationCrossEncoderWithQueryExpansion.parquet")
df_11 = pd.read_parquet("parquets/BM25PseudoRelevanceFeedback.parquet")
df_12 = pd.read_parquet("/run/media/tahas44/Yeni Birim/Technarts/Intern/NLP/InformationRetrieval/dense/parquets/SentenceTransformer.parquet")

# %%
df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12], ignore_index=True)
df
# Out:
#                                                Method  recall_5_mean  \
# 0     Bag of Words - Porter's Stemmer Queries Stemmed      10.287783
# 1                        Bag of Words - Lemmatization      10.360816
# 2           TF-IDF - Porter's Stemmer Queries Stemmed      12.394036
# 3                              TF-IDF - Lemmatization      12.413277
# 4             BM25 - Porter's Stemmer Queries Stemmed      14.478316
# 5                                BM25 - Lemmatization      14.593247
# 6               BM25 - Lemmatization Numbers Replaced      13.627131
# 7                BM25 - Lemmatization Numbers Deleted      14.544665
# 8                  BM25 - Lemmatization Cross Encoder      15.759954
# 9   BM25 - Lemmatization Cross Encoder With Query ...      15.642264
# 10                        BM25PseudoRelevanceFeedback      16.024472
# 11                               Sentence Transformer      12.089882
#
# ...

# %%
df[["Method", "f_score_10_mean"]]
# Out:
#                                                Method  f_score_10_mean
# 0     Bag of Words - Porter's Stemmer Queries Stemmed        13.458986
# 1                        Bag of Words - Lemmatization        13.615675
# 2           TF-IDF - Porter's Stemmer Queries Stemmed        16.012440
# 3                              TF-IDF - Lemmatization        16.214134
# 4             BM25 - Porter's Stemmer Queries Stemmed        19.340120
# 5                                BM25 - Lemmatization        19.510940
# 6               BM25 - Lemmatization Numbers Replaced        18.193116
# 7                BM25 - Lemmatization Numbers Deleted        19.336915
# 8                  BM25 - Lemmatization Cross Encoder        19.673399
# 9   BM25 - Lemmatization Cross Encoder With Query ...        19.385480
# 10                        BM25PseudoRelevanceFeedback        22.355875
# 11                               Sentence Transformer        14.959802

# %%
df[["Method", "NDCG_10_mean"]]
# Out:
#                                                Method  NDCG_10_mean
# 0     Bag of Words - Porter's Stemmer Queries Stemmed      0.429764
# 1                        Bag of Words - Lemmatization      0.430649
# 2           TF-IDF - Porter's Stemmer Queries Stemmed      0.476669
# 3                              TF-IDF - Lemmatization      0.475855
# 4             BM25 - Porter's Stemmer Queries Stemmed      0.508130
# 5                                BM25 - Lemmatization      0.506285
# 6               BM25 - Lemmatization Numbers Replaced      0.501126
# 7                BM25 - Lemmatization Numbers Deleted      0.502874
# 8                  BM25 - Lemmatization Cross Encoder      0.811885
# 9   BM25 - Lemmatization Cross Encoder With Query ...      0.811250
# 10                        BM25PseudoRelevanceFeedback      0.808502
# 11                               Sentence Transformer      0.703160
