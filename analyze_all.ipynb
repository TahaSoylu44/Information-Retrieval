# %%
import pandas as pd

df_1 = pd.read_parquet("sparse/parquets/BagofWordsLemmatization.parquet")
df_2 = pd.read_parquet("sparse/parquets/BagofWordsPortersStemmer.parquet")
df_3 = pd.read_parquet("sparse/parquets/BagofWordsPorterStemmerQueriesStemmed.parquet")
df_4 = pd.read_parquet("sparse/parquets/BM25-LemmatizationNumbersReplaced.parquet")
df_5 = pd.read_parquet("sparse/parquets/BM25Lemmatization.parquet")
df_6 = pd.read_parquet("sparse/parquets/BM25LemmatizationCrossEncoder.parquet")
df_7 = pd.read_parquet("sparse/parquets/BM25LemmatizationCrossEncoderWithQueryExpansion.parquet")
df_8 = pd.read_parquet("sparse/parquets/BM25LemmatizationNumbersDeleted.parquet")
df_9 = pd.read_parquet("sparse/parquets/BM25PorterStemmer.parquet")
df_10 = pd.read_parquet("sparse/parquets/BM25PorterStemmerQueriesStemmed.parquet")
df_11 = pd.read_parquet("sparse/parquets/BM25PseudoRelevanceFeedback.parquet")
df_12 = pd.read_parquet("sparse/parquets/TF-IDFLemmatization.parquet")
df_13 = pd.read_parquet("sparse/parquets/TF-IDFPorterStemmer.parquet")
df_14 = pd.read_parquet("sparse/parquets/TF-IDFPorterStemmerQueriesStemmed.parquet")
df_15 = pd.read_parquet("dense/parquets/SentenceTransformer.parquet")
df_16 = pd.read_parquet("dense/parquets/SenTransformerMulti_qa.parquet")
df_17 = pd.read_parquet("dense/parquets/SenTransformerMinilm_l12.parquet")
df_18 = pd.read_parquet("dense/parquets/minilm_l12_reranking.parquet")
df_19 = pd.read_parquet("hybrid_search.parquet")

df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19], ignore_index=True)

# %%
df
# Out:
#                                                Method  recall_5_mean  \
# 0                        Bag of Words - Lemmatization      10.360816
# 1                     Bag of Words - Porter's Stemmer       7.398910
# 2     Bag of Words - Porter's Stemmer Queries Stemmed      10.287783
# 3               BM25 - Lemmatization Numbers Replaced      13.627131
# 4                                BM25 - Lemmatization      14.593247
# 5                  BM25 - Lemmatization Cross Encoder      15.759954
# 6   BM25 - Lemmatization Cross Encoder With Query ...      15.642264
# 7                BM25 - Lemmatization Numbers Deleted      14.544665
# 8                             BM25 - Porter's Stemmer       9.352940
# 9             BM25 - Porter's Stemmer Queries Stemmed      14.478316
# 10                        BM25PseudoRelevanceFeedback      16.024472
# 11                             TF-IDF - Lemmatization      12.413277
# 12                          TF-IDF - Porter's Stemmer       8.381096
# ...

# %%
df.columns
# Out:
# Index(['Method', 'recall_5_mean', 'recall_5_std', 'recall_5_max',
#        'recall_5_min', 'recall_10_mean', 'recall_10_std', 'recall_10_max',
#        'recall_10_min', 'precision_5_mean', 'precision_5_std',
#        'precision_5_max', 'precision_5_min', 'precision_10_mean',
#        'precision_10_std', 'precision_10_max', 'precision_10_min',
#        'f_score_5_mean', 'f_score_5_std', 'f_score_5_max', 'f_score_5_min',
#        'f_score_10_mean', 'f_score_10_std', 'f_score_10_max', 'f_score_10_min',
#        'MAP_5', 'MAP_10', 'NDCG_5_mean', 'NDCG_5_std', 'NDCG_5_max',
#        'NDCG_5_min', 'NDCG_10_mean', 'NDCG_10_std', 'NDCG_10_max',
#        'NDCG_10_min', 'Unnamed: 0'],
#       dtype='str')

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df
# Out:
#                                                Method  recall_5_mean  \
# 0                        Bag of Words - Lemmatization      10.360816
# 1                     Bag of Words - Porter's Stemmer       7.398910
# 2     Bag of Words - Porter's Stemmer Queries Stemmed      10.287783
# 3               BM25 - Lemmatization Numbers Replaced      13.627131
# 4                                BM25 - Lemmatization      14.593247
# 5                  BM25 - Lemmatization Cross Encoder      15.759954
# 6   BM25 - Lemmatization Cross Encoder With Query ...      15.642264
# 7                BM25 - Lemmatization Numbers Deleted      14.544665
# 8                             BM25 - Porter's Stemmer       9.352940
# 9             BM25 - Porter's Stemmer Queries Stemmed      14.478316
# 10                        BM25PseudoRelevanceFeedback      16.024472
# 11                             TF-IDF - Lemmatization      12.413277
# 12                          TF-IDF - Porter's Stemmer       8.381096
# ...

# %%
method_type = []

for i in range(14):
    method_type.append("LEXICOGRAPHIC")

for i in range(4):
    method_type.append("SEMANTIC")

method_type.append("HYBRID")

# %%
df.insert(1, "Method Type", method_type)

# %%
df
# Out:
#                                                Method    Method Type  \
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 4                                BM25 - Lemmatization  LEXICOGRAPHIC
# 5                  BM25 - Lemmatization Cross Encoder  LEXICOGRAPHIC
# 6   BM25 - Lemmatization Cross Encoder With Query ...  LEXICOGRAPHIC
# 7                BM25 - Lemmatization Numbers Deleted  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 10                        BM25PseudoRelevanceFeedback  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# ...

# %%
df.loc[18, "Method Type"] = "HYBRID"

# %%
df
# Out:
#                                                Method    Method Type  \
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 4                                BM25 - Lemmatization  LEXICOGRAPHIC
# 5                  BM25 - Lemmatization Cross Encoder  LEXICOGRAPHIC
# 6   BM25 - Lemmatization Cross Encoder With Query ...  LEXICOGRAPHIC
# 7                BM25 - Lemmatization Numbers Deleted  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 10                        BM25PseudoRelevanceFeedback  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# ...

# %%
df.isna().sum()
# Out:
# Method               0
# Method Type          0
# recall_5_mean        0
# recall_5_std         0
# recall_5_max         0
# recall_5_min         0
# recall_10_mean       0
# recall_10_std        0
# recall_10_max        0
# recall_10_min        0
# precision_5_mean     0
# precision_5_std      0
# precision_5_max      0
# precision_5_min      0
# precision_10_mean    0
# precision_10_std     0
# precision_10_max     0
# precision_10_min     0
# f_score_5_mean       0
# f_score_5_std        0
# f_score_5_max        0
# f_score_5_min        0
# f_score_10_mean      0
# f_score_10_std       0
# f_score_10_max       0
# f_score_10_min       0
# MAP_5                0
# MAP_10               0
# NDCG_5_mean          0
# NDCG_5_std           0
# NDCG_5_max           0
# NDCG_5_min           0
# NDCG_10_mean         0
# NDCG_10_std          0
# NDCG_10_max          0
# NDCG_10_min          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 36 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Method             19 non-null     str
#  1   Method Type        19 non-null     str
#  2   recall_5_mean      19 non-null     float64
#  3   recall_5_std       19 non-null     float64
#  4   recall_5_max       19 non-null     float64
#  5   recall_5_min       19 non-null     float64
#  6   recall_10_mean     19 non-null     float64
#  7   recall_10_std      19 non-null     float64
#  8   recall_10_max      19 non-null     float64
#  9   recall_10_min      19 non-null     float64
#  10  precision_5_mean   19 non-null     float64
#  11  precision_5_std    19 non-null     float64
#  12  precision_5_max    19 non-null     float64
#  13  precision_5_min    19 non-null     float64
#  14  precision_10_mean  19 non-null     float64
#  15  precision_10_std   19 non-null     float64
# ...

# %%
df.to_csv("all_methods_results.csv")

# %%
df[["Method", "Method Type", "recall_5_mean"]].sort_values(by="recall_5_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 15                            SenTransformer multi_qa       SEMANTIC
# 14                               Sentence Transformer       SEMANTIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 17                               minilm_l12_reranking       SEMANTIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# ...

# %%
df[["Method", "Method Type", "precision_5_mean"]].sort_values(by="precision_5_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 15                            SenTransformer multi_qa       SEMANTIC
# 14                               Sentence Transformer       SEMANTIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 7                BM25 - Lemmatization Numbers Deleted  LEXICOGRAPHIC
# ...

# %%
df[["Method", "Method Type", "f_score_5_mean"]].sort_values(by="f_score_5_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 15                            SenTransformer multi_qa       SEMANTIC
# 14                               Sentence Transformer       SEMANTIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 17                               minilm_l12_reranking       SEMANTIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# ...

# %%
df[["Method", "Method Type", "recall_10_mean"]].sort_values(by="recall_10_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 15                            SenTransformer multi_qa       SEMANTIC
# 14                               Sentence Transformer       SEMANTIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 17                               minilm_l12_reranking       SEMANTIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 6   BM25 - Lemmatization Cross Encoder With Query ...  LEXICOGRAPHIC
# ...

# %%
df[["Method", "Method Type", "precision_10_mean"]].sort_values(by="precision_10_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 15                            SenTransformer multi_qa       SEMANTIC
# 14                               Sentence Transformer       SEMANTIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# 17                               minilm_l12_reranking       SEMANTIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# ...

# %%
df[["Method", "Method Type", "f_score_10_mean"]].sort_values(by="f_score_10_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 15                            SenTransformer multi_qa       SEMANTIC
# 14                               Sentence Transformer       SEMANTIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 17                               minilm_l12_reranking       SEMANTIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 7                BM25 - Lemmatization Numbers Deleted  LEXICOGRAPHIC
# ...

# %%
df[["Method", "Method Type", "MAP_5"]].sort_values(by="MAP_5", ascending=True)
# Out:
#                                                Method    Method Type     MAP_5
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC  0.056182
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC  0.063347
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC  0.072112
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC  0.079560
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC  0.080840
# 15                            SenTransformer multi_qa       SEMANTIC  0.093419
# 14                               Sentence Transformer       SEMANTIC  0.093745
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC  0.096138
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC  0.097513
# 16                          SenTransformer minilm_l12       SEMANTIC  0.099883
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC  0.108940
# ...

# %%
df[["Method", "Method Type", "MAP_10"]].sort_values(by="MAP_10", ascending=True)
# Out:
#                                                Method    Method Type    MAP_10
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC  0.068984
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC  0.078554
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC  0.091605
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC  0.094823
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC  0.096886
# 15                            SenTransformer multi_qa       SEMANTIC  0.111127
# 14                               Sentence Transformer       SEMANTIC  0.111715
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC  0.115298
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC  0.117186
# 16                          SenTransformer minilm_l12       SEMANTIC  0.118783
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC  0.134112
# ...

# %%
df[["Method", "Method Type", "NDCG_5_mean"]].sort_values(by="NDCG_5_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 7                BM25 - Lemmatization Numbers Deleted  LEXICOGRAPHIC
# 4                                BM25 - Lemmatization  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 14                               Sentence Transformer       SEMANTIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# ...

# %%
df[["Method", "Method Type", "NDCG_10_mean"]].sort_values(by="NDCG_10_mean", ascending=True)
# Out:
#                                                Method    Method Type  \
# 2     Bag of Words - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 0                        Bag of Words - Lemmatization  LEXICOGRAPHIC
# 11                             TF-IDF - Lemmatization  LEXICOGRAPHIC
# 13          TF-IDF - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 1                     Bag of Words - Porter's Stemmer  LEXICOGRAPHIC
# 3               BM25 - Lemmatization Numbers Replaced  LEXICOGRAPHIC
# 7                BM25 - Lemmatization Numbers Deleted  LEXICOGRAPHIC
# 4                                BM25 - Lemmatization  LEXICOGRAPHIC
# 9             BM25 - Porter's Stemmer Queries Stemmed  LEXICOGRAPHIC
# 12                          TF-IDF - Porter's Stemmer  LEXICOGRAPHIC
# 8                             BM25 - Porter's Stemmer  LEXICOGRAPHIC
# 14                               Sentence Transformer       SEMANTIC
# 16                          SenTransformer minilm_l12       SEMANTIC
# ...
